-- %% [markdown]
-- #datbricks dea(data engineer asscoate)-demo
-- ###spark overview medallion project

-- %% [markdown]
-- #Creating the "External Location" for the "Storage Credential"(dea_course_ext_sc)
-- we have already created the Storage Credential via the databricks UI

-- %% [markdown]
-- # Access the container gizmobox

-- %%
%fs ls 'abfss://gizmobox@databricksdemo001.dfs.core.windows.net/'

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS databricksdemo001_gizmobox
URL 'abfss://gizmobox@databricksdemo001.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL dea_course_ext_sc)
COMMENT 'Apache Spark ETL project'

-- %%
%fs ls 'abfss://gizmobox@databricksdemo001.dfs.core.windows.net/'

-- %%
%fs ls 'abfss://gizmobox@databricksdemo001.dfs.core.windows.net/landing/external_data/payments'
