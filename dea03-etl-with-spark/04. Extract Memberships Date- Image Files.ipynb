-- %% [markdown]
-- # Extract Data from the Memberships - Image Files
--
-- #### 1. Query Memberships File using binary file format
-- #### 2. Create Memberships view in Bronze schema

-- %% [markdown]
-- ## 1. Query Memberships File using binary file format

-- %%
select * 
from binaryFile.`/Volumes/gizmobox/landing/operation_data/memberships/*`

-- %%
select * 
from binaryFile.`/Volumes/gizmobox/landing/operation_data/memberships/*/*.png`

-- %% [markdown]
-- ## 2. Create Memberships view in Bronze schema

-- %%
CREATE OR REPLACE VIEW  gizmobox.bronze.v_memberships
AS
select * 
from binaryFile.`/Volumes/gizmobox/landing/operation_data/memberships/*`

-- %%
select * from gizmobox.bronze.v_memberships
