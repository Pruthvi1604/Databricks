-- %% [markdown]
-- # Data profiling in Databricks
-- 1. Profile Data using UI
-- 2. Profile Data using DBUTILS Package (dbutils.data.summarise method)
-- 3. Profile Data manually
--     -COUNT
--
--     -COUNT_IF
--
--     -MIN
--
--     -MAX
--
--     -WHERE clause

-- %% [markdown]
-- #1. Profile Data using UI

-- %%
select * from gizmobox.bronze.v_customers;
-- Out:
-- Databricks data profile. Run in Databricks to view.

-- %% [markdown]
-- #2. Profile Data using DBUTILS Package (dbutils.data.summarise method)

-- %%
%python
customers_df = spark.table("gizmobox.bronze.v_customers")

dbutils.data.summarize(customers_df)

-- %% [markdown]
-- #3. Profiling Data manually

-- %% [markdown]
-- 3.1 COUNT Fucntions

-- %%
select count(*), count(customer_id), count(email), count(telephone) from gizmobox.bronze.v_customers;

-- %% [markdown]
-- 3.1 COUNT_IF Function

-- %%
select count(*), count_if(customer_id is null), count_if(email is null), count_if(telephone is null) from gizmobox.bronze.v_customers;

-- %% [markdown]
-- 3.2 WHERE Clause

-- %%
select count(*) 
from gizmobox.bronze.v_customers 
where customer_id is null;

-- %% [markdown]
-- 3.4 DISTINCT Keyword

-- %%
SELECT count(*), count(DISTINCT customer_id)
FROM gizmobox.bronze.v_customers
WHERE customer_id IS NOT NULL;
